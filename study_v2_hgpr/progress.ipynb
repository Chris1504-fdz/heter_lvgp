# %% [markdown]
# # Sweep progress — `study_v2_hgpr`
# One bar per acquisition config: **completed runs / 90** (90 = n_rep{3,5,10} × 30 seeds).
# Reads `results/` directly, so it works while the sweep is running — **just re-run the cell below to refresh** (Ctrl-Enter).

# %%
import sys
STUDY_DIR = "/data/zhq7531/IDEAL/hetero_lvgp/study_v2_hgpr"
sys.path.insert(0, STUDY_DIR)
from utils import StudyResults

# lightweight: plot_progress only globs the results dir (no run loading)
StudyResults([], f"{STUDY_DIR}/results").plot_progress(target_per_acq=90)
